# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_dataset = datasets.CIFAR10(root='./data',\
              train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
                                batch_size=32, shuffle=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 170M/170M [03:09<00:00, 899kB/s]

# %%
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
        nn.ZeroPad2d((0, 1, 0, 1)),
        nn.BatchNorm2d(64, momentum=0.82),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(128, momentum=0.82),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(256, momentum=0.8),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Flatten(),
        nn.Linear(256 * 5 * 5, 1),
        nn.Sigmoid()
    )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %%
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)

adversarial_loss = nn.BCELoss()

optimizer_G = optim.Adam(generator.parameters()\
                         , lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
                         , lr=lr, betas=(beta1, beta2))

# %%
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):
       
        real_images = batch[0].to(device) 
       
        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)
       
        real_images = real_images.to(device)

        optimizer_D.zero_grad()
       
        z = torch.randn(real_images.size(0), latent_dim, device=device)
      
        fake_images = generator(z)

        real_loss = adversarial_loss(discriminator\
                                     (real_images), valid)
        fake_loss = adversarial_loss(discriminator\
                                     (fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2
    
        d_loss.backward()
        optimizer_D.step()

        optimizer_G.zero_grad()
      
        gen_images = generator(z)
        
        g_loss = adversarial_loss(discriminator(gen_images), valid)
        g_loss.backward()
        optimizer_G.step()
       
        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.4842 Generator Loss: 1.2597
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.7243 Generator Loss: 0.7870
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.6540 Generator Loss: 0.9545
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.6496 Generator Loss: 1.1253
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.6729 Generator Loss: 1.0149
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.6959 Generator Loss: 0.7804
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.5365 Generator Loss: 1.1409
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.5393 Generator Loss: 1.2769
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.6009 Generator Loss: 1.0424
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.6006 Generator Loss: 0.9842
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.5966 Generator Loss: 1.2268
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.6988 Generator Loss: 1.0413
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.7015 Generator Loss: 0.6834
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.6445 Generator Loss: 0.8905
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.7632 Generator Loss: 0.7911
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.6286 Generator Loss: 1.0891
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.7140 Generator Loss: 0.7373
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.6309 Generator Loss: 1.0623
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.6100 Generator Loss: 0.9721
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.6639 Generator Loss: 1.0754
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.6234 Generator Loss: 1.0855
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.5700 Generator Loss: 1.0099
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.6907 Generator Loss: 0.9453
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.5372 Generator Loss: 1.3518
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.5612 Generator Loss: 0.8975
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.4992 Generator Loss: 1.5602
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.5280 Generator Loss: 1.1826
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.4421 Generator Loss: 1.5814
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.5101 Generator Loss: 1.4183
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.5703 Generator Loss: 1.9148
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.4948 Generator Loss: 1.1925
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.6026 Generator Loss: 1.3000
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.8242 Generator Loss: 1.1331
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.5643 Generator Loss: 2.1151
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.5843 Generator Loss: 1.0261
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.5045 Generator Loss: 1.0794
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.5382 Generator Loss: 1.4865
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.5446 Generator Loss: 1.2140
# Epoch [3/10]                        Batch 900/1563 Discriminator Loss: 0.5914 Generator Loss: 0.8106
# Epoch [3/10]                        Batch 1000/1563 Discriminator Loss: 0.6344 Generator Loss: 0.5565
# Epoch [3/10]                        Batch 1100/1563 Discriminator Loss: 0.4296 Generator Loss: 1.8661
# Epoch [3/10]                        Batch 1200/1563 Discriminator Loss: 0.3688 Generator Loss: 1.4571
# Epoch [3/10]                        Batch 1300/1563 Discriminator Loss: 0.6402 Generator Loss: 1.2345
# Epoch [3/10]                        Batch 1400/1563 Discriminator Loss: 0.4808 Generator Loss: 0.7691
# Epoch [3/10]                        Batch 1500/1563 Discriminator Loss: 0.7237 Generator Loss: 0.9016
# Epoch [4/10]                        Batch 100/1563 Discriminator Loss: 0.5845 Generator Loss: 0.7029
# Epoch [4/10]                        Batch 200/1563 Discriminator Loss: 0.4676 Generator Loss: 1.1209
# Epoch [4/10]                        Batch 300/1563 Discriminator Loss: 1.0323 Generator Loss: 1.2850
# Epoch [4/10]                        Batch 400/1563 Discriminator Loss: 0.7538 Generator Loss: 1.7669
# Epoch [4/10]                        Batch 500/1563 Discriminator Loss: 0.7303 Generator Loss: 0.8100
# Epoch [4/10]                        Batch 600/1563 Discriminator Loss: 0.5856 Generator Loss: 1.2956
# Epoch [4/10]                        Batch 700/1563 Discriminator Loss: 0.5158 Generator Loss: 1.2304
# Epoch [4/10]                        Batch 800/1563 Discriminator Loss: 0.6566 Generator Loss: 1.4369
# Epoch [4/10]                        Batch 900/1563 Discriminator Loss: 0.5719 Generator Loss: 1.5342
# Epoch [4/10]                        Batch 1000/1563 Discriminator Loss: 0.7308 Generator Loss: 0.7958
# Epoch [4/10]                        Batch 1100/1563 Discriminator Loss: 0.3678 Generator Loss: 1.4135
# Epoch [4/10]                        Batch 1200/1563 Discriminator Loss: 0.6229 Generator Loss: 1.1164
# Epoch [4/10]                        Batch 1300/1563 Discriminator Loss: 0.5263 Generator Loss: 1.5416
# Epoch [4/10]                        Batch 1400/1563 Discriminator Loss: 0.5813 Generator Loss: 1.2183
# Epoch [4/10]                        Batch 1500/1563 Discriminator Loss: 0.4589 Generator Loss: 2.4829
# Epoch [5/10]                        Batch 100/1563 Discriminator Loss: 0.4980 Generator Loss: 1.5047
# Epoch [5/10]                        Batch 200/1563 Discriminator Loss: 0.5080 Generator Loss: 1.1399
# Epoch [5/10]                        Batch 300/1563 Discriminator Loss: 0.7154 Generator Loss: 0.6351
# Epoch [5/10]                        Batch 400/1563 Discriminator Loss: 0.5704 Generator Loss: 1.2364
# Epoch [5/10]                        Batch 500/1563 Discriminator Loss: 0.5502 Generator Loss: 1.4216
# Epoch [5/10]                        Batch 600/1563 Discriminator Loss: 0.7496 Generator Loss: 0.8948
# Epoch [5/10]                        Batch 700/1563 Discriminator Loss: 0.4979 Generator Loss: 0.9716
# Epoch [5/10]                        Batch 800/1563 Discriminator Loss: 0.6289 Generator Loss: 1.2901
# Epoch [5/10]                        Batch 900/1563 Discriminator Loss: 0.6334 Generator Loss: 1.5061
# Epoch [5/10]                        Batch 1000/1563 Discriminator Loss: 0.3524 Generator Loss: 1.4694
# Epoch [5/10]                        Batch 1100/1563 Discriminator Loss: 0.5198 Generator Loss: 1.1415
# Epoch [5/10]                        Batch 1200/1563 Discriminator Loss: 0.6307 Generator Loss: 1.5564
# Epoch [5/10]                        Batch 1300/1563 Discriminator Loss: 1.0537 Generator Loss: 0.5376
# Epoch [5/10]                        Batch 1400/1563 Discriminator Loss: 0.7161 Generator Loss: 0.8969
# Epoch [5/10]                        Batch 1500/1563 Discriminator Loss: 0.5204 Generator Loss: 1.1558
# Epoch [6/10]                        Batch 100/1563 Discriminator Loss: 0.6582 Generator Loss: 1.0325
# Epoch [6/10]                        Batch 200/1563 Discriminator Loss: 0.5307 Generator Loss: 1.6022
# Epoch [6/10]                        Batch 300/1563 Discriminator Loss: 0.5188 Generator Loss: 1.7644
# Epoch [6/10]                        Batch 400/1563 Discriminator Loss: 0.4969 Generator Loss: 1.4766
# Epoch [6/10]                        Batch 500/1563 Discriminator Loss: 0.3859 Generator Loss: 1.4283
# Epoch [6/10]                        Batch 600/1563 Discriminator Loss: 0.5937 Generator Loss: 1.1704
# Epoch [6/10]                        Batch 700/1563 Discriminator Loss: 0.4668 Generator Loss: 0.9124
# Epoch [6/10]                        Batch 800/1563 Discriminator Loss: 0.4204 Generator Loss: 1.6547
# Epoch [6/10]                        Batch 900/1563 Discriminator Loss: 0.6538 Generator Loss: 1.3917
# Epoch [6/10]                        Batch 1000/1563 Discriminator Loss: 0.8215 Generator Loss: 1.4137
# Epoch [6/10]                        Batch 1100/1563 Discriminator Loss: 0.2367 Generator Loss: 1.1825
# Epoch [6/10]                        Batch 1200/1563 Discriminator Loss: 0.5346 Generator Loss: 1.2819
# Epoch [6/10]                        Batch 1300/1563 Discriminator Loss: 0.4984 Generator Loss: 1.5241
# Epoch [6/10]                        Batch 1400/1563 Discriminator Loss: 0.5464 Generator Loss: 0.8625
# Epoch [6/10]                        Batch 1500/1563 Discriminator Loss: 0.5687 Generator Loss: 1.2246
# Epoch [7/10]                        Batch 100/1563 Discriminator Loss: 0.5004 Generator Loss: 1.1979
# Epoch [7/10]                        Batch 200/1563 Discriminator Loss: 0.7271 Generator Loss: 0.7090
# Epoch [7/10]                        Batch 300/1563 Discriminator Loss: 0.4067 Generator Loss: 1.3131
# Epoch [7/10]                        Batch 400/1563 Discriminator Loss: 0.5816 Generator Loss: 1.2060
# Epoch [7/10]                        Batch 500/1563 Discriminator Loss: 0.6800 Generator Loss: 1.6543
# Epoch [7/10]                        Batch 600/1563 Discriminator Loss: 0.5602 Generator Loss: 1.7836
# Epoch [7/10]                        Batch 700/1563 Discriminator Loss: 0.3226 Generator Loss: 1.0819
# Epoch [7/10]                        Batch 800/1563 Discriminator Loss: 0.6795 Generator Loss: 0.7834
# Epoch [7/10]                        Batch 900/1563 Discriminator Loss: 0.3933 Generator Loss: 1.4948
# Epoch [7/10]                        Batch 1000/1563 Discriminator Loss: 0.3706 Generator Loss: 1.8060
# Epoch [7/10]                        Batch 1100/1563 Discriminator Loss: 0.8295 Generator Loss: 0.8424
# Epoch [7/10]                        Batch 1200/1563 Discriminator Loss: 0.5062 Generator Loss: 1.1059
# Epoch [7/10]                        Batch 1300/1563 Discriminator Loss: 0.6035 Generator Loss: 1.1354
# Epoch [7/10]                        Batch 1400/1563 Discriminator Loss: 0.6776 Generator Loss: 1.6126
# Epoch [7/10]                        Batch 1500/1563 Discriminator Loss: 0.8482 Generator Loss: 1.2792
# Epoch [8/10]                        Batch 100/1563 Discriminator Loss: 0.3369 Generator Loss: 1.2857
# Epoch [8/10]                        Batch 200/1563 Discriminator Loss: 0.4511 Generator Loss: 1.7027
# Epoch [8/10]                        Batch 300/1563 Discriminator Loss: 0.6527 Generator Loss: 0.6628
# Epoch [8/10]                        Batch 400/1563 Discriminator Loss: 0.6538 Generator Loss: 1.9922
# Epoch [8/10]                        Batch 500/1563 Discriminator Loss: 0.7304 Generator Loss: 1.1667
# Epoch [8/10]                        Batch 600/1563 Discriminator Loss: 0.5845 Generator Loss: 1.0880
# Epoch [8/10]                        Batch 700/1563 Discriminator Loss: 0.7529 Generator Loss: 1.2215
# Epoch [8/10]                        Batch 800/1563 Discriminator Loss: 0.5586 Generator Loss: 1.4408
# Epoch [8/10]                        Batch 900/1563 Discriminator Loss: 0.5921 Generator Loss: 1.6313
# Epoch [8/10]                        Batch 1000/1563 Discriminator Loss: 0.6935 Generator Loss: 1.5195
# Epoch [8/10]                        Batch 1100/1563 Discriminator Loss: 0.8331 Generator Loss: 0.4094
# Epoch [8/10]                        Batch 1200/1563 Discriminator Loss: 0.5573 Generator Loss: 1.2661
# Epoch [8/10]                        Batch 1300/1563 Discriminator Loss: 0.8724 Generator Loss: 1.3325
# Epoch [8/10]                        Batch 1400/1563 Discriminator Loss: 0.3879 Generator Loss: 1.0212
# Epoch [8/10]                        Batch 1500/1563 Discriminator Loss: 0.5820 Generator Loss: 1.7045
# Epoch [9/10]                        Batch 100/1563 Discriminator Loss: 0.4966 Generator Loss: 1.0523
# Epoch [9/10]                        Batch 200/1563 Discriminator Loss: 0.4623 Generator Loss: 0.9710
# Epoch [9/10]                        Batch 300/1563 Discriminator Loss: 0.6060 Generator Loss: 1.0019
# Epoch [9/10]                        Batch 400/1563 Discriminator Loss: 0.7172 Generator Loss: 0.9467
# Epoch [9/10]                        Batch 500/1563 Discriminator Loss: 0.9020 Generator Loss: 0.9839
# Epoch [9/10]                        Batch 600/1563 Discriminator Loss: 0.4871 Generator Loss: 1.6192
# Epoch [9/10]                        Batch 700/1563 Discriminator Loss: 0.4689 Generator Loss: 0.6357
# Epoch [9/10]                        Batch 800/1563 Discriminator Loss: 0.5210 Generator Loss: 1.0754
# Epoch [9/10]                        Batch 900/1563 Discriminator Loss: 0.6098 Generator Loss: 1.1332
# Epoch [9/10]                        Batch 1000/1563 Discriminator Loss: 1.1685 Generator Loss: 1.0642
# Epoch [9/10]                        Batch 1100/1563 Discriminator Loss: 0.3877 Generator Loss: 1.2827
# Epoch [9/10]                        Batch 1200/1563 Discriminator Loss: 0.6633 Generator Loss: 1.7447
# Epoch [9/10]                        Batch 1300/1563 Discriminator Loss: 0.5138 Generator Loss: 1.7859
# Epoch [9/10]                        Batch 1400/1563 Discriminator Loss: 0.3676 Generator Loss: 1.4399
# Epoch [9/10]                        Batch 1500/1563 Discriminator Loss: 0.6338 Generator Loss: 0.8656
# Epoch [10/10]                        Batch 100/1563 Discriminator Loss: 0.2931 Generator Loss: 2.2486
# Epoch [10/10]                        Batch 200/1563 Discriminator Loss: 0.4401 Generator Loss: 1.2963
# Epoch [10/10]                        Batch 300/1563 Discriminator Loss: 0.6589 Generator Loss: 0.7241
# Epoch [10/10]                        Batch 400/1563 Discriminator Loss: 0.6265 Generator Loss: 1.3487
# Epoch [10/10]                        Batch 500/1563 Discriminator Loss: 0.4113 Generator Loss: 1.1508
# Epoch [10/10]                        Batch 600/1563 Discriminator Loss: 0.5430 Generator Loss: 0.6603
# Epoch [10/10]                        Batch 700/1563 Discriminator Loss: 0.6703 Generator Loss: 1.2791
# Epoch [10/10]                        Batch 800/1563 Discriminator Loss: 0.5197 Generator Loss: 1.4325
# Epoch [10/10]                        Batch 900/1563 Discriminator Loss: 0.4259 Generator Loss: 1.7566
# Epoch [10/10]                        Batch 1000/1563 Discriminator Loss: 0.6503 Generator Loss: 0.8774
# Epoch [10/10]                        Batch 1100/1563 Discriminator Loss: 0.7063 Generator Loss: 2.0207
# Epoch [10/10]                        Batch 1200/1563 Discriminator Loss: 0.6603 Generator Loss: 1.4289
# Epoch [10/10]                        Batch 1300/1563 Discriminator Loss: 0.8433 Generator Loss: 1.6763
# Epoch [10/10]                        Batch 1400/1563 Discriminator Loss: 0.3928 Generator Loss: 1.3553
# Epoch [10/10]                        Batch 1500/1563 Discriminator Loss: 0.4220 Generator Loss: 1.4927
